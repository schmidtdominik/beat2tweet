# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.9.0-py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (23.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2023.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.25.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (4.0.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, urllib3, multiprocess, responses, huggingface-hub, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.9.0 huggingface-hub-0.12.1 multiprocess-0.70.14 responses-0.18.0 urllib3-1.26.14 xxhash-3.2.0

# %%
import numpy as np
import string
import os
import torch
import torchvision
import pandas as pd
from datasets import load_dataset
import torch.nn as nn 
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from torch.optim.lr_scheduler import StepLR

import warnings
# UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() 
# or sourceTensor.clone().detach().requires_grad_(True) rather than torch.tensor(sourceTensor)
warnings.simplefilter("ignore", category=UserWarning)

# %% [markdown]
# ## Data loading and cleanup

# %%
# Load embeddings, which is a dictionary (ytid -> 512-dim feature vector)
try:
    embeddings = np.load("embeddings.npy", allow_pickle=True).item()
    ids = sorted(list(embeddings.keys()))
    print(f"Loaded {len(ids)} feature vectors.")
except:
    print("Error loading embeddings")

# Load MusicCaps captions
try:
  ds = load_dataset('google/MusicCaps', split='train')
  df = pd.DataFrame({'ytid':ds['ytid'], 'caption':ds['caption'], 'is_eval': ds['is_audioset_eval']})
  # discard entries without embedding
  df_captions = df[df.ytid.isin(ids)] 
  print(f"Loaded {df.shape[0]} captions, using {df_captions.shape[0]} ")
except:
    print("Error loading captions")

def cleaning_text(caption):
    table = str.maketrans('','',string.punctuation)
    caption.replace("-"," ")
    # split the sentences into words
    desc = caption.split()
    #converts to lower case
    desc = [word.lower() for word in desc]
    #remove punctuation from each token
    desc = [word.translate(table) for word in desc]
    #remove hanging 's and a 
    desc = [word for word in desc if(len(word)>1)]
    #remove tokens with numbers in them
    desc = [word for word in desc if(word.isalpha())]
    #convert back to string
    caption = ' '.join(desc)

    return caption

def preprocess_captions(captions):
    for audio_file,caption in captions.items():
        caption = cleaning_text(caption)
        captions[audio_file]= caption
            
    return captions

captions = dict(zip(df.ytid,df.caption))
captions = preprocess_captions(captions)

# define a vocabulary
def text_vocabulary(descriptions):
    captions = list(descriptions.values())
    vocab = set(['<start>', '<end>', ':', ',', ';'])
    for caption in captions:
        for token in caption.strip().split():
            vocab.add(token)
    return vocab

# force <pad> to have idx 0 (convention)
vocab = ['<pad>'] + list(text_vocabulary(captions))

word_to_idx = {word: idx for idx, word in enumerate(vocab)}
idx_to_word = {idx: word for word, idx in word_to_idx.items()}

def tokenize(caption):
    caption = cleaning_text(caption)
    token_list = []
    # Add <start> to the beginning and <end> to the end of each caption
    caption_list = ["<start>"] + caption.split() + ["<end>"]
    token_list = [word_to_idx[word] for word in caption_list]
    return token_list 

df_captions['tokenized_caption'] = df_captions['caption'].apply(tokenize)
train_df = df_captions[~df_captions.is_eval]
eval_df = df_captions[df_captions.is_eval]
df_captions.head()
# Out:
# Loaded 5493 feature vectors.
# WARNING:datasets.builder:Using custom data configuration google--MusicCaps-7925612b943f961b
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/google___csv/google--MusicCaps-7925612b943f961b/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# Loaded 5521 captions, using 5493
# <ipython-input-141-3566b24db762>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_captions['tokenized_caption'] = df_captions['caption'].apply(tokenize)
#           ytid                                            caption  is_eval  \
# 0  -0Gj8-vB1q4  The low quality recording features a ballad so...     True
# 1  -0SdAVK79lg  This song features an electric guitar as the m...    False
# 2  -0vPFx-wRRI  a male voice is singing a melody with changing...     True
# 3  -0xzrMun0Rs  This song contains digital drums playing a sim...     True
# 4  -1LrH01Ei1w  This song features a rubber instrument being p...    False
#
#                                    tokenized_caption
# 0  [343, 5267, 3761, 311, 2156, 1632, 5558, 3133,...
# 1  [343, 602, 3133, 1632, 1171, 3100, 941, 665, 5...
# 2  [343, 4470, 1719, 2579, 2369, 910, 804, 5582, ...
# 3  [343, 602, 3133, 860, 1544, 4688, 2165, 4729, ...
# 4  [343, 602, 3133, 1632, 834, 3105, 2250, 4711, ...

# %%
# Define the audio captioning dataset
class AudioCaptionDataset(Dataset):
    def __init__(self, captions, embeddings):
        self.captions = captions
        self.embeddings = embeddings

    def __len__(self):
        return len(self.captions)

    def __getitem__(self, idx):
        caption = self.captions[idx]
        ytid = caption['ytid']
        embedding = self.embeddings[ytid]
        tokenized_caption = torch.LongTensor(caption['tokenized_caption'])
        return {"embedding": embedding, "tokenized_caption": tokenized_caption}

# Define the collate function for the audio captioning dataset
def collate_fn_try(batch):
    embeddings = []
    captions = []
    for b in batch:
        embeddings.append(torch.from_numpy(b['embedding']))
        captions.append(torch.tensor(b['tokenized_caption']))
    padded_embeddings = nn.utils.rnn.pad_sequence(embeddings, batch_first=True)
    padded_captions = nn.utils.rnn.pad_sequence(captions, batch_first=True, padding_value=word_to_idx["<pad>"])  # Use the <pad> index for padding
    return padded_embeddings, padded_captions

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1, dropout=0.4):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout = nn.Dropout(p=dropout)
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.fc.weight.data.uniform_(-0.1, 0.1)
        self.fc.bias.data.fill_(0)

    def forward(self, input, features):
        embedded = self.embedding(input)
        embedded = self.dropout(embedded)
        # concatenate audio features and input embedding
        inputs = torch.cat((features.unsqueeze(1), embedded), dim=1)
        output, hidden = self.lstm(inputs)
        output = self.fc(output)[:,1:,:]

        return output, hidden

# %% [markdown]
# ```
# class LSTMModel(nn.Module):
#     def __init__(self, input_size, hidden_size, output_size, num_layers=1):
#         super().__init__()
#         self.hidden_size = hidden_size
#         self.num_layers = num_layers
#         self.embedding = nn.Embedding(input_size, hidden_size)
#         self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
#         self.fc = nn.Linear(hidden_size, output_size)
#
#     def forward(self, input, hidden=None):
#         c0 = torch.zeros(self.num_layers, input.size(0), self.hidden_size).to(input.device)
#         if hidden is None:
#             h0 = torch.zeros(self.num_layers, input.size(0), self.hidden_size).to(input.device)
#         else:
#             if num_layers == 1: h0 = hidden.unsqueeze(0)
#             else: h0 = torch.cat((hidden.unsqueeze(0),
#                             torch.zeros(num_layers-1, input.size(0), hidden_size).to(device)), dim=0)
#         hidden = (h0, c0)
#
#         embedded = self.embedding(input)
#         output, hidden = self.lstm(embedded, hidden)
#         output = self.fc(output)
#
#         return output, hidden
# ```

# %% [markdown]
# ## Model training

# %%
# Instantiate the model
vocab_size = len(vocab)
input_size = vocab_size
hidden_size = 512
output_size = vocab_size
num_layers = 2
model = LSTMModel(input_size, hidden_size, output_size, num_layers)

# Instantiate the dataset
train_dataset = AudioCaptionDataset(train_df.to_dict('records'),
                {id: embeddings[id] for id in train_df.ytid.unique()})
eval_dataset = AudioCaptionDataset(eval_df.to_dict('records'),
                {id: embeddings[id] for id in eval_df.ytid.unique()})

# Train the model
lr = 5e-4
batch_size = 64
num_epochs = 50
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
criterion = nn.CrossEntropyLoss(ignore_index=word_to_idx['<pad>'])
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
loss_fn = nn.CrossEntropyLoss(ignore_index=word_to_idx['<pad>'])

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn_try)
eval_dataloader = DataLoader(eval_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn_try)

# %%
# load a batch
batch = next(iter(train_dataloader))
print(f"Embeddings batch, shape={batch[0].shape}")
print(f"Captions batch, shape={batch[1].shape}")
# Out:
# Embeddings batch, shape=torch.Size([64, 512])
# Captions batch, shape=torch.Size([64, 133])

# %%
def generate_caption(i, max_caption_length=64, show_true_caption=True, show_ytid=True):

  ytid = df_captions.iloc[i]["ytid"]
  true_caption = df_captions.iloc[i]["caption"]
  embedding = torch.from_numpy(embeddings[ytid])

  x = embedding.unsqueeze(0).to(device, dtype=torch.float)
  model.eval()
  # breaks if starting sequence is only one token (?)
  caption = torch.tensor([word_to_idx[word] for word in ['<pad>', '<start>']]).unsqueeze(0).to(device)

  # Generate the caption word by word
  with torch.no_grad():
      while caption[0][-1] != word_to_idx['<end>'] and len(caption[0]) < max_caption_length:
          logits, hidden = model(caption[:, :-1], x)
          predicted_word_index = logits.argmax(-1)[:, -1].item()
          predicted_word = idx_to_word[predicted_word_index]
          caption = torch.cat([caption, torch.tensor([[predicted_word_index]], dtype=torch.long).to(device)], dim=1)

  predicted_caption = ' '.join([idx_to_word[word_idx] for word_idx in caption[0].tolist()][2:-1])

  if show_ytid: print(f"https://www.youtube.com/watch?v={ytid}")
  if show_true_caption: print(f"True caption: {true_caption}")
  print(f"Predicted caption: {predicted_caption}")

# %%
# Train the model
for epoch in range(num_epochs):
    model.train()  # set model to train mode
    for i, (x, captions) in enumerate(train_dataloader):
        x = x.to(device, dtype=torch.float)
        captions = captions.to(device, dtype=torch.long)
        optimizer.zero_grad()
        logits, hidden = model(captions[:, :-1], x)
        loss = loss_fn(logits.reshape(-1, vocab_size), captions[:, 1:].reshape(-1))
        loss.backward()
        optimizer.step()
    scheduler.step()

    model.eval()  # set model to eval mode
    eval_loss = 0
    with torch.no_grad():
        for x, captions in eval_dataloader:
            x = x.to(device, dtype=torch.float)
            captions = captions.to(device, dtype=torch.long)
            logits, hidden = model(captions[:, :-1], x)
            loss = loss_fn(logits.reshape(-1, vocab_size), captions[:, 1:].reshape(-1))
            eval_loss += loss.item() * x.size(0)  # accumulate loss for entire eval dataset
        eval_loss /= len(eval_dataloader.dataset)  # compute average eval loss
        
    
    print(f"Epoch {epoch}, train loss {loss.item():.4f}, eval loss {eval_loss:.4f}")
    generate_caption(0, show_ytid=(epoch==0), show_true_caption=(epoch==0)) # eval song
    generate_caption(1, show_ytid=(epoch==0), show_true_caption=(epoch==0)) # train song
    print("")
# Out:
# Epoch 0, train loss 5.7788, eval loss 5.8476
# https://www.youtube.com/watch?v=-0Gj8-vB1q4
# True caption: The low quality recording features a ballad song that contains sustained strings, mellow piano melody and soft female vocal singing over it. It sounds sad and soulful, like something you would hear at Sunday services.
# Predicted caption: this this is is is is is is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# https://www.youtube.com/watch?v=-0SdAVK79lg
# True caption: This song features an electric guitar as the main instrument. The guitar plays a descending run in the beginning then plays an arpeggiated chord followed by a double stop hammer on to a higher note and a descending slide followed by a descending chord run. The percussion plays a simple beat using rim shots. The percussion plays in common time. The bass plays only one note on the first count of each bar. The piano plays backing chords. There are no voices in this song. The mood of this song is relaxing. This song can be played in a coffee shop.
# Predicted caption: this this is is is is is is the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Epoch 1, train loss 5.7529, eval loss 5.7368
# Predicted caption: this is quality features features the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# Predicted caption: this is quality features features the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Epoch 2, train loss 5.6029, eval loss 5.5421
# Predicted caption: this is quality features the the the is is is with with and and and the the the is is is and and and and the the the is is is in and the the the is is is in and the the the is is is in and the the the is is is in and the the the is
# Predicted caption: this is quality features the the the is is is with with and and and the the the is is is and and and and the the the is is is in and the the the is is is in and the the the is is is in and the the the is is is in and the the the is
#
# Epoch 3, train loss 4.9781, eval loss 5.1915
# Predicted caption: this low is features an playing with the with song melody is the playing and the the is is and and and the the
# Predicted caption: this low is features an playing with the with song with is and playing and the the song is is be playing and and
#
# Epoch 4, train loss 5.2219, eval loss 4.8650
# Predicted caption: this the is features an playing with the playing main the melody bass is the playing bass the and bass the the bass is is playing playing in the the background background is the playing song the the atmosphere is is an playing and the the song of is the played song the this atmosphere is is no played in in
# Predicted caption: this the is features an playing with the playing main the melody bass is the playing bass the and bass the the bass is is playing playing in the the background background is the playing song the the atmosphere is is an playing and the the song of is the played song the this atmosphere is is no played in in
#
# Epoch 5, train loss 4.6503, eval loss 4.5855
# Predicted caption: this the is recording an of guitar the with main the with main the with main the with bass the and bass the and bass the and bass the and atmosphere the is quality an this of piece the this song is is an played instrumental in the the background background of the the atmosphere of is the played of the
# Predicted caption: this the is recording an of guitar the with main the with main the with main the with bass the and bass the and bass the and bass the and atmosphere the is quality an this of piece the this song is is an played instrumental in the the background background of the the atmosphere of is the played of the
#
# Epoch 6, train loss 4.3070, eval loss 4.3774
# Predicted caption: this the is recording an of instrumental the the tempo tempo is is medium with with an drumming bass bass guitar guitar and and drumming the the song song is is noisy noisy and and the the song quality is is noisy noisy in
# Predicted caption: this the is recording an of instrumental the the tempo tempo is is medium fast with with an drumming bass bass guitar guitar and and drumming the the song song is is noisy noisy and and the the song quality is is noisy noisy in
#
# Epoch 7, train loss 4.2315, eval loss 4.2187
# Predicted caption: the the song quality is features medium with played kick the and bass bass guitar guitar and and groovy percussion bass it it sounds sounds passionate and and passionate the
# Predicted caption: the the song quality is features medium with played an the bass bass guitar guitar and and the percussion song is is playing by the the song song is is noisy by and the the song quality is is poor noisy and
#
# Epoch 8, train loss 4.1397, eval loss 4.1077
# Predicted caption: this the is song an with tempo the of tempo the is tempo fast with with the acoustic acoustic guitar guitar and and the the bass song is is playing by the the acoustic background guitar is is playing by the the acoustic background guitar is is playing by the the acoustic background guitar is is playing by the the acoustic
# Predicted caption: this the is song an with tempo the of tempo the is tempo fast with with the an acoustic drum guitar beat and the the bass quality is is provided by by the the acoustic bass guitar guitar is the playing acoustic the guitar bass is plays playing the the bass background guitar is plays playing the the bass background guitar
#
# Epoch 9, train loss 3.9144, eval loss 4.0181
# Predicted caption: this the is song instrumental with the the tempo tempo is is medium fast with with an drumming acoustic rhythm guitar and accompaniment keyboard the accompaniment song is is emotional mellow and and passionate the the song quality is is poor poor
# Predicted caption: this the is song instrumental with the the tempo tempo is is medium fast with with an drumming acoustic rhythm guitar and accompaniment keyboard the the song song is is emotional mellow and and romantic the the audio quality quality is is poor poor
#
# Epoch 10, train loss 3.8099, eval loss 3.9651
# Predicted caption: this the song song is features an the acoustic main guitar melody the the bass quality is is provided by by an the acoustic acoustic drum guitar beat the the atmosphere atmosphere is is an poor electronic piece drum this to piece could this be piece used in in the the soundtrack soundtrack of of drama movie movie during
# Predicted caption: the the song quality is features an by electric the guitar guitar melody the the song quality is is an noisy tempo with with the the music song is is energetic mellow and and cheerful the
#
# Epoch 11, train loss 3.9225, eval loss 3.9484
# Predicted caption: this the is song an with tempo an with guitar the playing song the the song quality is is poor poor and quality quality
# Predicted caption: this the is song an with tempo an of guitar the playing song the the song quality is is poor poor and quality the
#
# Epoch 12, train loss 3.8118, eval loss 3.9100
# Predicted caption: this this is song an the instrumental recording of is the played main the melody melody is is played played by by the the percussion bass and plays the the main bass melody plays the the bass bass guitar plays the the bass bass guitar plays the the bass bass guitar plays the the bass bass guitar plays the the bass
# Predicted caption: this the is song an with instrumental an the acoustic song guitar is is playing played simple on beat the the bass background is is playing by simple the acoustic bass guitar is the playing acoustic the guitar bass is plays playing simple the melody bass is plays playing simple the melody bass is plays playing simple the melody bass is
#
# Epoch 13, train loss 4.0561, eval loss 3.8908
# Predicted caption: this this song song features features male male voice voice singing is the singing main in melody the this song is is an by instrumental percussion the playing mood melody of this the song song is is played played in in the the background background of can the be song played this in song this this song song can can be
# Predicted caption: this this song song features features male the voice main is melody singing in in the the background background of can the be sound played and in the the background background of can the be sound played this in song the this mood song song is is romantic played this in song this this song song can can be be played
#
# Epoch 14, train loss 3.6026, eval loss 3.8599
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main in melody the this bass is is played by by the the percussion bass and plays the the root bass notes plays the the root bass notes plays the the root bass notes plays the the root bass
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main in melody the this bass is is played by by the the percussion bass and plays the the root bass notes plays the the root bass notes plays the the root bass notes plays the the root bass
#
# Epoch 15, train loss 3.8268, eval loss 3.8436
# Predicted caption: this we song have features an male acoustic voice guitar is playing played simple on melody the in bass the and bass side is is playing played the on melody the this bass song may is be played played in in the movie background
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main in melody the the bass background is is playing by simple the acoustic rhythm drums is the playing acoustic the guitar atmosphere is is groovy by and the the acoustic atmosphere drums is is provided by by the
#
# Epoch 16, train loss 4.0005, eval loss 3.8203
# Predicted caption: this this song song features features male male voice voice singing is the played main in melody the this bass is is played by by the the percussion bass plays plays the the root root notes notes of the the chords bass of plays the the root bass notes plays the the root bass notes plays the the root bass notes
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main on melody the this bass is is played by by the the acoustic bass guitar plays the the root bass notes plays the the root bass notes and the the acoustic atmosphere guitar is is playing by by
#
# Epoch 17, train loss 3.8292, eval loss 3.8085
# Predicted caption: this we song have features an male acoustic voice guitar is is played played on on the the floor same kick melody and and the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays the the chords bass of plays
# Predicted caption: this we song have features an the electric song guitar is plays played simple on beat the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays the the chords bass of plays the the chords bass of plays the the
#
# Epoch 18, train loss 3.4306, eval loss 3.8060
# Predicted caption: this we song have features an male electric voice guitar is plays played simple on beat the this bass is is played by on the the percussion same and chords the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the root bass notes plays
# Predicted caption: this this song song features features male the voice main is melody singing this in is the accompanied percussion by playing the the main bass melody plays the the root bass notes plays the the root root notes notes of the the chords bass of plays the the root bass notes plays the the root root notes notes of the the
#
# Epoch 19, train loss 3.9723, eval loss 3.7839
# Predicted caption: this we song have features an male electric voice guitar is plays played simple on melody the this bass is is played by on the the percussion same and chords the the mood bass of is the played sound this this song song can can be be played played in in movie movie
# Predicted caption: this we song have features an the electric song guitar is plays played simple on beat the the bass bass plays plays the the root root notes notes of the the chords song of is the played sound this this song song can can be be played played in in movie movie
#
# Epoch 20, train loss 4.3196, eval loss 3.7738
# Predicted caption: this we song have features an male electric voice guitar is is played played on on the the floor kick kick and and the the same same note melody the is song played and in the the background background of can the be sound played this in song the this mood song of is the romantic mood this this song song
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the bass bass and is the playing root the notes rhythm of is the played acoustic by guitar the the atmosphere atmosphere is is sentimental poor this this piece is could an be instrumental used
#
# Epoch 21, train loss 3.5619, eval loss 3.7738
# Predicted caption: this we song have features an male electric voice guitar is is played played on on the the floor kick kick and and the the same same note melody the the song song is is played by by the the voice bass of plays the the same bass melody and the the bass bass plays plays the the root root notes
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the acoustic bass guitar is is playing playing simple the melody rhythm while is the playing acoustic the drum rhythm beat is the playing atmosphere the the atmosphere background is is poor by this the
#
# Epoch 22, train loss 3.8231, eval loss 3.7648
# Predicted caption: this we song have features an male electric voice guitar is is played played on on the the floor kick kick and and the the same bass note plays is the played root in notes the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the bass bass and is the playing acoustic the guitar rhythm is is playing played simple by tune the the atmosphere background is is an by electronic the drum piece beat is the played atmosphere
#
# Epoch 23, train loss 3.7011, eval loss 3.7627
# Predicted caption: this we song have features an male electric voice guitar is playing played simple on melody the this bass is is played by on the the percussion same and chords the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays
# Predicted caption: this this song song features features the the main main melody melody the the voice sound is is played played on on the the end kick of and the the sound sound of is the played sound on there the are song no this other is instruments played in in this the song song this can is be played played in
#
# Epoch 24, train loss 4.0632, eval loss 3.7587
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the acoustic bass guitar is is playing playing simple the melody rhythm is is played by by the the acoustic bass drums the the atmosphere atmosphere is is groovy poor and this the piece recording
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the acoustic bass guitar is is playing playing simple the melody rhythm the is atmosphere provided this in piece the the piece quality is is poor poor this quality piece could could be be used
#
# Epoch 25, train loss 3.8488, eval loss 3.7572
# Predicted caption: this we song have features an male electric voice guitar is playing played simple on melody the this bass is is played by on the the percussion same and chords the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays
# Predicted caption: this this song song features features the the main main melody melody the the voice sound is is played played on on the the end kick of and the the sound sound of is the played sound on there the are song no this other is instruments played in in this the song song this can song be can played be
#
# Epoch 26, train loss 3.7680, eval loss 3.7473
# Predicted caption: this we song have features an the electric song guitar is plays played simple on beat the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the root bass note plays and the the root same note of the the chords song is is played
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main by melody the the bass bass is is playing by simple the beat bass the plays atmosphere the the atmosphere background is is an by electronic the drum piece beat the the atmosphere quality is is poor poor
#
# Epoch 27, train loss 3.9711, eval loss 3.7459
# Predicted caption: this we song have features an male electric voice guitar is playing played simple on melody the this bass is is played by on the the percussion same and chords the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main by melody the the bass bass is plays playing simple the beat bass the plays atmosphere the is atmosphere slow this and piece could could be be used used in in the the soundtrack soundtrack of of an
#
# Epoch 28, train loss 3.4790, eval loss 3.7383
# Predicted caption: this we song have features an the electric song guitar is playing played simple on beat the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays the the chords bass of plays the the chords same of chords the this
# Predicted caption: this the song song is features played the on main the melody melody is is played played by by the the percussion bass and plays the the root root notes notes of the the chords bass and plays the the root same notes of the the chords song and is the played feel in to the the end quality of of
#
# Epoch 29, train loss 3.4708, eval loss 3.7425
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the snare bass and plays the the root background notes of the the chords rhythm the is atmosphere provided this by piece the this piece piece could could be be used used in in the
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the snare bass and plays the the root background notes of the the chords background the can atmosphere be is played sampled by for an the advertisement opening and
#
# Epoch 30, train loss 3.5803, eval loss 3.7386
# Predicted caption: this we song have features an male electric voice guitar is is played played on on the the floor kick count and and the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the main bass melody plays the the main bass melody plays the
# Predicted caption: this this song song features features the the main main melody melody the the voice melody is is played played on on the the floor percussion count and and the the bass bass plays plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays the
#
# Epoch 31, train loss 3.9221, eval loss 3.7349
# Predicted caption: this we song have features an the accordion song playing is the played main on melody the this bass is is played by on the the percussion percussion and plays the the root bass notes plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody is is playing played simple on with the the end bass of plays the the chords bass of plays the the acoustic rhythm drums is the played acoustic by drum the beat atmosphere the is atmosphere vibrant this this piece is could an
#
# Epoch 32, train loss 3.8045, eval loss 3.7320
# Predicted caption: this we song have features an male accordion voice playing is the played main in melody the this bass is is played by on the the percussion percussion and plays the the root bass notes plays the the root root notes notes of the the chords bass of plays the the chords bass of plays the the chords bass of plays
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main on melody the the bass background is is playing by simple the beat bass the plays atmosphere the the atmosphere background is is an by electronic the drum piece beat the the atmosphere quality is is poor poor
#
# Epoch 33, train loss 3.6168, eval loss 3.7364
# Predicted caption: this we is have an classical instrumental music the piece tempo is is slow fast with with an an acoustic acoustic guitar guitar riff harmony the the music music is is youthful mellow mellow cheerful pulsating and and vivacious this this music is is an live instrumental instrumental
# Predicted caption: the the song tempo is is medium fast tempo tempo with with groovy keyboard bass harmony line and and other other percussion instrumentation the the song song is is emotional mellow and and passionate the the song song is is an live amateur performance recording with
#
# Epoch 34, train loss 3.8953, eval loss 3.7348
# Predicted caption: this the song song is features an the accordion main playing melody the the main background melody is is played by by the the acoustic bass guitar and the the bass bass guitar is is playing playing simple the melody rhythm the the atmosphere background is is an by electronic the drum piece beat the the atmosphere atmosphere is is vibrant
# Predicted caption: this the song song is features an the acoustic main guitar melody playing the the main bass melody plays is the played main on melody the the bass background is is playing by simple the beat rhythm the the atmosphere atmosphere is is vibrant poor and this the piece recording could is be used used in in the the soundtrack soundtrack
#
# Epoch 35, train loss 3.6948, eval loss 3.7318
# Predicted caption: this the is song an with instrumental an the electric tempo guitar is is playing played simple by with the an bass electric guitar guitar the accompaniment song is is emotional by and the the audio audio quality is is poor poor
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays bass notes plays the the root root notes notes of the the chords bass of plays the
#
# Epoch 36, train loss 3.9753, eval loss 3.7335
# Predicted caption: this the song song is features an the accordion main playing melody the the main background melody is is played by by the the acoustic bass guitar and the the bass bass guitar is is playing playing simple the melody rhythm the is atmosphere provided this by piece the this piece piece could could be be used used in in the
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays bass notes plays the the root root notes notes of the the chords bass of plays the
#
# Epoch 37, train loss 3.7691, eval loss 3.7331
# Predicted caption: this the song song is features an the acoustic electric guitar guitar playing playing simple the melody bass is plays played simple on with the the snare snare and and the the voice bass is is playing by simple the rhythm rhythm is is played by by the the acoustic drums drums the the atmosphere atmosphere is is energetic poor and
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody is is played played on on the the percussion percussion this and is has played moderate on times the the mood bass of is the played sound this there is is no played in in this
#
# Epoch 38, train loss 3.7587, eval loss 3.7306
# Predicted caption: this we is have an classical instrumental music the piece tempo is is slow fast with with an violin acoustic harmony guitar and and keyboard keyboard accompaniment accompaniment the the music music is is youthful buoyant buoyant groovy groovy and and groovy this this song is is an live instrumental performance
# Predicted caption: this the song song is features an the acoustic electric guitar guitar playing playing simple simple melody bass with plays the the main bass melody and the the bass bass guitar is and playing the the rhythm background is is provided by by the the acoustic drums drums the the atmosphere atmosphere is is groovy poor and
#
# Epoch 39, train loss 3.5254, eval loss 3.7310
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the guitar bass of is the by acoustic the guitar guitar and and the the bass bass guitar is is playing played simple on with the the end bass of is the by acoustic the guitar rhythm and the the acoustic
# Predicted caption: the the song tempo is is medium fast tempo tempo with with groovy keyboard bass harmony line and and guitar guitar accompaniment the the song song is is emotional mellow and and romantic the the song audio is quality poor
#
# Epoch 40, train loss 3.8527, eval loss 3.7310
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the floor bass kick and and the the bass guitar guitar is is playing by simple the rhythm rhythm is is groovy by and the the acoustic audio drums is is playing by simple the rhythm rhythm is is simple by
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the chords bass of plays the
#
# Epoch 41, train loss 3.6558, eval loss 3.7282
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the floor bass kick and and the the snare guitar is is playing by simple the rhythm bass is is playing by simple the rhythm rhythm is is groovy by and the the bass audio is is energetic by and the
# Predicted caption: this the song song is features an the acoustic electric guitar guitar playing playing simple simple melody bass with plays the the main bass melody and the the bass bass guitar is and playing the the rhythm background is is provided by by the the acoustic acoustic drums guitar the and atmosphere has is the energetic atmosphere sound this this piece
#
# Epoch 42, train loss 3.9281, eval loss 3.7305
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the an floor electric cymbal guitar and and the other bass guitar guitar the the song song is is emotional simple and and groovy the
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays bass notes plays the the root root notes notes of the the chords bass of plays the
#
# Epoch 43, train loss 4.0507, eval loss 3.7309
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the an floor electric cymbal guitar and and the other bass guitar guitar the the song song is is emotional simple and and groovy the
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody is is played played on on the the percussion percussion this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords
#
# Epoch 44, train loss 3.6877, eval loss 3.7306
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the floor bass kick and and the the snare guitar is is playing by simple the rhythm bass is is playing by simple the rhythm rhythm is is groovy by and the the bass audio is is energetic by and the
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the chords bass of plays the
#
# Epoch 45, train loss 3.8256, eval loss 3.7329
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the floor bass kick and and the the snare bass is is playing by simple the rhythm bass is is playing by simple the rhythm rhythm is is groovy by and the the acoustic audio drums is is playing by simple
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the chords bass of plays the
#
# Epoch 46, train loss 3.7961, eval loss 3.7307
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the piano bass section plays is the by acoustic the guitar guitar and and the the bass bass guitar is is playing by simple the rhythm rhythm is is played by by the the acoustic drums drums the the atmosphere quality
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the root bass notes plays the
#
# Epoch 47, train loss 3.6161, eval loss 3.7281
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the floor bass kick and and the the snare guitar is is playing by simple the rhythm bass is is playing by simple the rhythm rhythm is is groovy by and the the acoustic audio drums is is playing by simple
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the chords bass of plays the
#
# Epoch 48, train loss 3.8010, eval loss 3.7280
# Predicted caption: this the song song is features an the accordion main playing melody the in main background melody is is played played by by the the percussion bass and plays the the root root notes notes of the the chords bass of plays the the chords root of guitar the and song guitar is plays played the on mood the of song
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the chords bass of plays the
#
# Epoch 49, train loss 3.9903, eval loss 3.7307
# Predicted caption: this the is song an with instrumental an the electric song guitar is is playing played simple on with the the floor bass kick and and the the guitar guitar is is playing by simple the rhythm bass is is playing by simple the rhythm rhythm is is groovy by and the the bass audio is is energetic by and the
# Predicted caption: this this song song features features the the main main melody melody the the voice bass is plays played the on main the melody melody this is is accompanied by by percussion percussion playing playing simple the beat bass the plays bass the plays root notes notes of the the chords bass of plays the the chords bass of plays the

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 10547246

# %% [markdown]
# ### Model assessment
# Predict with the trained LSTM model

# %%
i = 3
generate_caption(i)
# Out:
# https://www.youtube.com/watch?v=-0xzrMun0Rs
# True caption: This song contains digital drums playing a simple groove along with two guitars. One strumming chords along with the snare the other one playing a melody on top. An e-bass is playing the footnote while a piano is playing a major and minor chord progression. A trumpet is playing a loud melody alongside the guitar. All the instruments sound flat and are being played by a keyboard. There are little bongo hits in the background panned to the left side of the speakers. Apart from the music you can hear eating sounds and a stomach rumbling. This song may be playing for an advertisement.
# Predicted caption: the the song tempo is is medium fast tempo with with steady keyboard drumming accompaniment rhythm and and other other percussion instruments playing the the song song is is emotional spirited and and romantic the the audio audio quality quality is is poor poor
